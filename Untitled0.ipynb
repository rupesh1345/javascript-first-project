# %% [markdown]
# <a href="https://colab.research.google.com/github/rupesh1345/javascript-first-project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
df_temperature = pd.read_csv('/content/temperature.csv', encoding='utf-8')
df_temperature.head()
# Out:
#    record_id  month  day  year  AverageTemperatureFahr  \
# 0     474376      1    1  1853                     NaN
# 1     474377      2    1  1853                     NaN
# 2     474378      3    1  1853                     NaN
# 3     474379      4    1  1853                     NaN
# 4     474380      5    1  1853                     NaN
#
#    AverageTemperatureUncertaintyFahr      City country_id      Country  \
# 0                                NaN  Auckland        NEW  New Zealand
# 1                                NaN  Auckland        NEW  New Zealand
# 2                                NaN  Auckland        NEW  New Zealand
# 3                                NaN  Auckland        NEW  New Zealand
# 4                                NaN  Auckland        NEW  New Zealand
#
#   Latitude Longitude
# 0   36.17S   175.03E
# 1   36.17S   175.03E
# 2   36.17S   175.03E
# 3   36.17S   175.03E
# 4   36.17S   175.03E

# %%
df_temperature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48470 entries, 0 to 48469
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   record_id                          48470 non-null  int64
#  1   month                              48470 non-null  int64
#  2   day                                48470 non-null  int64
#  3   year                               48470 non-null  int64
#  4   AverageTemperatureFahr             47541 non-null  float64
#  5   AverageTemperatureUncertaintyFahr  47541 non-null  float64
#  6   City                               47986 non-null  object
#  7   country_id                         47986 non-null  object
#  8   Country                            47986 non-null  object
#  9   Latitude                           48470 non-null  object
#  10  Longitude                          48470 non-null  object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 4.1+ MB

# %%
# Set index for 'year' column
df_temperature.set_index('year', inplace=True)

# Yearly average air temperature calculation
df_temperature['average_temperature'] = df_temperature[['AverageTemperatureFahr', 'AverageTemperatureUncertaintyFahr']].mean(axis=1)

# Drop unwanted columns and reset the DataFrame
df_temperature = df_temperature[['average_temperature']]
df_temperature.reset_index(inplace=True)

df_temperature.head()
# Out:
#    year  average_temperature
# 0  1853                  NaN
# 1  1853                  NaN
# 2  1853                  NaN
# 3  1853                  NaN
# 4  1853                  NaN

# %%
# SMA over a period of 10 and 20 years
df_temperature['SMA_10'] = df_temperature.average_temperature.rolling(10, min_periods=1).mean()
df_temperature['SMA_20'] = df_temperature.average_temperature.rolling(20, min_periods=1).mean()

# Grean = Avg Air Temp, RED = 10 yrs, ORANG colors for the line plot
colors = ['green', 'red', 'orange']
# Line plot
df_temperature.plot(color=colors, linewidth=3, figsize=(12,6))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels =['Average air temperature', '10-years SMA', '20-years SMA'], fontsize=14)
plt.title('The yearly average air temperature in city', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Temperature [°C]', fontsize=16)
# Out:
# <ipython-input-8-1c92a0820bef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temperature['SMA_10'] = df_temperature.average_temperature.rolling(10, min_periods=1).mean()
# <ipython-input-8-1c92a0820bef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temperature['SMA_20'] = df_temperature.average_temperature.rolling(20, min_periods=1).mean()
# Text(0, 0.5, 'Temperature [°C]')

# %%
# CMA Air temperature
df_temperature['CMA'] = df_temperature.average_temperature.expanding().mean()

# green -Avg Air Temp and Orange -CMA
colors = ['green', 'orange']
# line plot
df_temperature[['average_temperature', 'CMA']].plot(color=colors, linewidth=3, figsize=(12,6))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels =['Average Air Temperature', 'CMA'], fontsize=14)
plt.title('The yearly average air temperature in city', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Temperature [°C]', fontsize=16)
# Out:
# Text(0, 0.5, 'Temperature [°C]')

# %%
# EMA Air Temperature
# Let's smoothing factor - 0.1
df_temperature['EMA_0.1'] = df_temperature.average_temperature.ewm(alpha=0.1, adjust=False).mean()
# Let's smoothing factor  - 0.3
df_temperature['EMA_0.3'] = df_temperature.average_temperature.ewm(alpha=0.3, adjust=False).mean()

# green - Avg Air Temp, red- smoothing factor - 0.1, yellow - smoothing factor  - 0.3
colors = ['green', 'red', 'yellow']
df_temperature[['average_temperature', 'EMA_0.1', 'EMA_0.3']].plot(color=colors, linewidth=3, figsize=(12,6), alpha=0.8)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels=['Average air temperature', 'EMA - alpha=0.1', 'EMA - alpha=0.3'], fontsize=14)
plt.title('The yearly average air temperature in city', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Temperature [°C]', fontsize=16)
# Out:
# Text(0, 0.5, 'Temperature [°C]')

# %%
# Plot autocorrelation function
plot_acf(df_temperature['average_temperature'])
plt.show()

# Plot autocorrelation function with specific number of lags (e.g., 30)
plot_acf(df_temperature['average_temperature'], lags=30)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py:2503: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)

# %%
from matplotlib import pyplot
from pandas.plotting import lag_plot
lag_plot(df_temperature)
pyplot.show()

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt

# Assuming df_temperature is your DataFrame containing the dataset

# Extract the target variable 'average_temperature'
target_variable = df_temperature['average_temperature']

# Split dataset for test and training
train = target_variable.iloc[:-7]
test = target_variable.iloc[-7:]

# Train ARIMA model
order = (5, 1, 0)  # (p, d, q) parameters
model = ARIMA(train, order=order)
model_fit = model.fit()

# Make predictions
forecast_steps = len(test)
predictions = model_fit.forecast(steps=forecast_steps)

# %%
# Convert predictions array to pandas Series
predictions_series = pd.Series(predictions, index=test.index)

# Print predicted and expected values
for index, (predicted, expected) in enumerate(zip(predictions_series, test)):
    print('predicted=%.3f, expected=%.3f' % (predicted, expected))
# Out:
# predicted=34.362, expected=31.201
# predicted=37.754, expected=39.285
# predicted=41.884, expected=43.772
# predicted=43.569, expected=46.750
# predicted=44.012, expected=49.671
# predicted=42.799, expected=48.525
# predicted=40.311, expected=nan

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt

# Load data
# Assuming df_temperature is your DataFrame containing the dataset

# Preprocess data (if necessary)
# Assuming no preprocessing is required

# Split data into train and test sets
train = df_temperature['average_temperature'].iloc[:-7]
test = df_temperature['average_temperature'].iloc[-7:]

# Choose model parameters
order = (5, 1, 0)  # Example parameters (p, d, q)

# Fit the ARIMA model
model = ARIMA(train, order=order)
model_fit = model.fit()

# Make predictions
forecast_steps = len(test)
predictions = model_fit.forecast(steps=forecast_steps)

# %%
# Visualize results (optional)
plt.plot(test.index, test, label='Actual')
plt.plot(test.index, predictions, color='red', label='Predicted')
plt.legend()
plt.show()
